# %%
# !pip install pyautogui

# %%
import pyautogui as pgui
import time
import pyperclip
from datetime import datetime, date, timedelta
import datetime

# %%
pgui.position()
# Out:
# Point(x=-1437, y=641)

# %%
pgui.size()
# Out:
# Size(width=1360, height=768)

# %%
pgui.click()

# %%
pgui.click(x=94, y=749, duration=1)

# %%
pgui.screenshot('sample.png')
# Out:
# <PIL.Image.Image image mode=RGB size=1360x768 at 0x21D34AA3E20>

# %%
pgui.screenshot('sample.png',region=(0,200,300,300))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x21D34E68B80>

# %%
pgui.FAILSAFE=True

# %%
pgui.click(x=125, y=750, duration=0.5)
pgui.write('explore',0.2)
#pgui.click(x=125, y=750, duration=0.5)
time.sleep(0.8)
pgui.hotkey('enter')

# %%
import pyautogui as pg

import time

import pyperclip

pg.press('win')

time.sleep(1)

pyperclip.copy('excel')

pg.hotkey('ctrl','v')

time.sleep(1)

pg.press('enter')

time.sleep(3)



pg.press('enter')

# %%
#excel起動
import pyautogui as pg

import time

import pyperclip

pgui.click(x=125, y=750, duration=0.5)
pgui.write('excel',0.2)


pg.press('enter')
