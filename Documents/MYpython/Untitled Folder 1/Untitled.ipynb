# %%
from bs4 import BeautifulSoup    # importする
soup = BeautifulSoup(html.content, "html.parser")    # HTMLを解析する
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d944f57f1703> in <module>
#       1 from bs4 import BeautifulSoup    # importする
# ----> 2 soup = BeautifulSoup(html.content, "html.parser")    # HTMLを解析する
#
# NameError: name 'html' is not defined

# %%
import requests
from bs4 import BeautifulSoup
# Webページを取得して解析する

load_url = "https://www.ymori.com/books/python2nen/test1.html"
html = requests.get(load_url)
soup = BeautifulSoup(html.content, "html.parser")

# HTML全体を表示する
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>Python2年生</title>
# </head>
# <body>
# <h2>第1章 Pythonでデータをダウンロード</h2>
# <ol>
# <li>スクレイピングってなに？</li>
# <li>Pythonをインストールしてみよう</li>
# <li>requestsでアクセスしてみよう</li>
# </ol>
# </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup
# Webページを取得して解析する

load_url = "https://www.label-bank.co.jp/blog/"
html = requests.get(load_url)
soup = BeautifulSoup(html.content, "html.parser")

# HTML全体を表示する
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 7]>
# <html class="ie ie7" lang="ja" prefix="og: http://ogp.me/ns#">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="ja" prefix="og: http://ogp.me/ns#">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8)  ]><!-->
# <html lang="ja" prefix="og: http://ogp.me/ns#">
# <!--<![endif]-->
# <!-- START: Benchmark Email Signup Form Code -->
# <!--JB Tracker--> <script type="text/javascript"> var _paq = _paq || []; (function(){ if(window.apScriptInserted) return; _paq.push(['clientToken', 'P%2bsIjEMd6oQ%3d']); var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0]; g.type='text/javascript'; g.async=true; g.defer=true; g.src='https://prod.benchmarkemail.com/tracker.bundle.js'; s.parentNode.insertBefore(g,s); window.apScriptInserted=true;})(); </script> <!--/JB Tracker--> <!-- BEGIN: Benchmark Email Signup Form Code -->
# <script id="lbscript1473575" src="https://lb.benchmarkemail.com//jp/code/lbformnew.js?mFcQnoBFKMQbs3fQcUI2E0itbgbM6uK5AWDo1Lzs5czWcWhdMJPEUcj9ybR%252Bnt%252Fk" type="text/javascript"></script><noscript>Please enable JavaScript <br/></noscript>
# <!-- END: Benchmark Email Signup Form Code -->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <title>食品表示ブログ - 食品表示実務者のための情報サイト</title>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.label-bank.co.jp/blog/xmlrpc.php" rel="pingback"/>
# <!--[if lt IE 9]>
# <script src="https://www.label-bank.co.jp/blog/wp-content/themes/iconic-one/js/html5.js" type="text/javascript"></script>
# <![endif]-->
# <!-- This site is optimized with the Yoast SEO plugin v3.1.2 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="食品表示実務者のための情報サイト" name="description"/>
# <meta content="noodp" name="robots"/>
# <link href="https://www.label-bank.co.jp/blog" rel="canonical"/>
# <link href="https://www.label-bank.co.jp/blog/page/2" rel="next"/>
# <meta content="ja_JP" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="食品表示ブログ - 食品表示実務者のための情報サイト" property="og:title"/>
# <meta content="食品表示実務者のための情報サイト" property="og:description"/>
# <meta content="https://www.label-bank.co.jp/blog" property="og:url"/>
# <meta content="食品表示ブログ" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="食品表示実務者のための情報サイト" name="twitter:description"/>
# <meta content="食品表示ブログ - 食品表示実務者のための情報サイト" name="twitter:title"/>
# <script type="application/ld+json">{"@context":"http:\/\/schema.org","@type":"WebSite","url":"https:\/\/www.label-bank.co.jp\/blog\/","name":"\u98df\u54c1\u8868\u793a\u306b\u95a2\u3059\u308b\u60c5\u5831\u767a\u4fe1\u30b5\u30a4\u30c8\u3000\u98df\u54c1\u8868\u793aBlog","potentialAction":{"@type":"SearchAction","target":"https:\/\/www.label-bank.co.jp\/blog\/?s={search_term_string}","query-input":"required name=search_term_string"}}</script>
# <script type="application/ld+json">{"@context":"http:\/\/schema.org","@type":"Organization","url":"https:\/\/www.label-bank.co.jp\/blog","sameAs":[],"name":"\u682a\u5f0f\u4f1a\u793e\u30e9\u30d9\u30eb\u30d0\u30f3\u30af","logo":""}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="https://www.label-bank.co.jp/blog/feed" rel="alternate" title="食品表示ブログ » フィード" type="application/rss+xml"/>
# <link href="https://www.label-bank.co.jp/blog/comments/feed" rel="alternate" title="食品表示ブログ » コメントフィード" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/72x72\/","ext":".png","source":{"concatemoji":"https:\/\/www.label-bank.co.jp\/blog\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.4.25"}};
# 			!function(e,n,t){var a;function i(e){var t=n.createElement("canvas"),a=t.getContext&&t.getContext("2d"),i=String.fromCharCode;return!(!a||!a.fillText)&&(a.textBaseline="top",a.font="600 32px Arial","flag"===e?(a.fillText(i(55356,56806,55356,56826),0,0),3e3<t.toDataURL().length):"diversity"===e?(a.fillText(i(55356,57221),0,0),t=a.getImageData(16,16,1,1).data,a.fillText(i(55356,57221,55356,57343),0,0),(t=a.getImageData(16,16,1,1).data)[0],t[1],t[2],t[3],!0):("simple"===e?a.fillText(i(55357,56835),0,0):a.fillText(i(55356,57135),0,0),0!==a.getImageData(16,16,1,1).data[0]))}function o(e){var t=n.createElement("script");t.src=e,t.type="text/javascript",n.getElementsByTagName("head")[0].appendChild(t)}t.supports={simple:i("simple"),flag:i("flag"),unicode8:i("unicode8"),diversity:i("diversity")},t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.simple&&t.supports.flag&&t.supports.unicode8&&t.supports.diversity||(a=function(){t.readyCallback()},n.addEventListener?(n.addEventListener("DOMContentLoaded",a,!1),e.addEventListener("load",a,!1)):(e.attachEvent("onload",a),n.attachEvent("onreadystatechange",function(){"complete"===n.readyState&&t.readyCallback()})),(a=t.source||{}).concatemoji?o(a.concatemoji):a.wpemoji&&a.twemoji&&(o(a.twemoji),o(a.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://www.label-bank.co.jp/blog/wp-content/plugins/fancier-author-box/css/ts-fab.min.css?ver=1.4" id="ts_fab_css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//netdna.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.css" id="font-awesome-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="https://fonts.googleapis.com/css?family=Ubuntu:400,700&amp;subset=latin,latin-ext" id="themonic-fonts-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.label-bank.co.jp/blog/wp-content/themes/iconic-one/style.css?ver=4.4.25" id="themonic-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://www.label-bank.co.jp/blog/wp-content/themes/iconic-one/custom.css?ver=4.4.25" id="custom-style-css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lt IE 9]>
# <link rel='stylesheet' id='themonic-ie-css'  href='https://www.label-bank.co.jp/blog/wp-content/themes/iconic-one/css/ie.css?ver=20130305' type='text/css' media='all' />
# <![endif]-->
# <link href="https://www.label-bank.co.jp/blog/wp-content/plugins/wordpress-popular-posts/style/wpp.css?ver=3.3.3" id="wordpress-popular-posts-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="https://www.label-bank.co.jp/blog/wp-includes/js/jquery/jquery.js?ver=1.11.3" type="text/javascript"></script>
# <script src="https://www.label-bank.co.jp/blog/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.2.1" type="text/javascript"></script>
# <script src="https://www.label-bank.co.jp/blog/wp-content/plugins/fancier-author-box/js/ts-fab.min.js?ver=1.4" type="text/javascript"></script>
# <link href="https://www.label-bank.co.jp/blog/wp-json/" rel="https://api.w.org/"/>
# <link href="https://www.label-bank.co.jp/blog/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://www.label-bank.co.jp/blog/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 4.4.25" name="generator"/>
# <style>
# 	.ts-fab-list li a { background-color: #e9e9e9; border: 1px solid #e9e9e9; color: #333; }
# 	.ts-fab-list li.active a { background-color: #16a1e7; border: 1px solid #16a1e7; color: #fff; }
# 	.ts-fab-tab { background-color: #fafafa; border: 2px solid #16a1e7; color: #555; }
# 	</style>
# <style>
# .scroll-back-to-top-wrapper {
#     position: fixed;
# 	opacity: 0;
# 	visibility: hidden;
# 	overflow: hidden;
# 	text-align: center;
# 	z-index: 99999999;
#     background-color: #777777;
# 	color: #eeeeee;
# 	width: 50px;
# 	height: 48px;
# 	line-height: 48px;
# 	right: 30px;
# 	bottom: 30px;
# 	padding-top: 2px;
# 	border-top-left-radius: 10px;
# 	border-top-right-radius: 10px;
# 	border-bottom-right-radius: 10px;
# 	border-bottom-left-radius: 10px;
# 	-webkit-transition: all 0.5s ease-in-out;
# 	-moz-transition: all 0.5s ease-in-out;
# 	-ms-transition: all 0.5s ease-in-out;
# 	-o-transition: all 0.5s ease-in-out;
# 	transition: all 0.5s ease-in-out;
# }
# .scroll-back-to-top-wrapper:hover {
# 	background-color: #888888;
#   color: #eeeeee;
# }
# .scroll-back-to-top-wrapper.show {
#     visibility:visible;
#     cursor:pointer;
# 	opacity: 1.0;
# }
# .scroll-back-to-top-wrapper i.fa {
# 	line-height: inherit;
# }
# .scroll-back-to-top-wrapper .fa-lg {
# 	vertical-align: 0;
# }
# </style><script type="text/javascript">
# 	window._wp_rp_static_base_url = 'https://wprp.zemanta.com/static/';
# 	window._wp_rp_wp_ajax_url = "https://www.label-bank.co.jp/blog/wp-admin/admin-ajax.php";
# 	window._wp_rp_plugin_version = '3.6';
# 	window._wp_rp_post_id = '2639';
# 	window._wp_rp_num_rel_posts = '4';
# 	window._wp_rp_thumbnails = false;
# 	window._wp_rp_post_title = '%E9%85%92%E9%A1%9E%E3%81%AE%E4%BF%9D%E5%AD%98%E3%81%AE%E3%81%9F%E3%82%81%E7%89%A9%E5%93%81%E3%82%92%E6%B7%B7%E5%92%8C%E3%81%99%E3%82%8B%E3%81%93%E3%81%A8%E3%81%8C%E3%81%A7%E3%81%8D%E3%82%8B%E9%85%92%E9%A1%9E%E3%81%AE%E5%93%81%E7%9B%AE%E7%AD%89%E3%82%92%E5%AE%9A%E3%82%81%E3%82%8B%E7%AD%89%E3%81%AE%E4%BB%B6%E3%81%AE%E4%B8%80%E9%83%A8%E6%94%B9%E6%AD%A3%E3%81%A8%E9%85%92%E9%A1%9E%E3%81%AB%E3%81%8A%E3%81%91%E3%82%8B%E6%B7%BB%E5%8A%A0%E7%89%A9%E3%81%AE%E7%95%99%E6%84%8F%E7%82%B9';
# 	window._wp_rp_post_tags = ['2021%E5%B9%B4', '%E9%85%92%E9%A1%9E', '%E6%B7%BB%E5%8A%A0%E7%89%A9', '%E9%A3%9F%E5%93%81%E8%A1%A8%E7%A4%BA', '%E9%A3%9F%E5%93%81%E8%A1%A8%E7%A4%BA', 'tr', 'br', 'td'];
# 	window._wp_rp_promoted_content = true;
# </script>
# <script async="" src="https://wprp.zemanta.com/static/js/loader.js?version=3.6" type="text/javascript"></script>
# <!-- BEGIN: WP Social Bookmarking Light -->
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/ja_JP/sdk.js#xfbml=1&version=v2.0";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <style type="text/css">
# .wp_social_bookmarking_light{
#     border: 0 !important;
#     padding: 10px 0 20px 0 !important;
#     margin: 0 !important;
# }
# .wp_social_bookmarking_light div{
#     float: left !important;
#     border: 0 !important;
#     padding: 0 !important;
#     margin: 0 5px 0px 0 !important;
#     min-height: 30px !important;
#     line-height: 18px !important;
#     text-indent: 0 !important;
# }
# .wp_social_bookmarking_light img{
#     border: 0 !important;
#     padding: 0;
#     margin: 0;
#     vertical-align: top !important;
# }
# .wp_social_bookmarking_light_clear{
#     clear: both !important;
# }
# #fb-root{
#     display: none;
# }
# .wsbl_twitter{
#     width: 100px;
# }
# .wsbl_facebook_like iframe{
#     max-width: none !important;
# }</style>
# <!-- END: WP Social Bookmarking Light -->
# <style id="custom-background-css" type="text/css">
# body.custom-background { background-color: #ededed; }
# </style>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-2092499-8', 'auto');
#   ga('send', 'pageview');
# </script>
# </head>
# <body class="home blog custom-background custom-font-enabled">
# <div class="hfeed site" id="page">
# <header class="site-header" id="masthead" role="banner">
# <div class="themonic-logo">
# <a href="https://www.label-bank.co.jp/blog/" rel="home" title="食品表示ブログ"><img alt="食品表示ブログ" src="https://www.label-bank.co.jp/blog/wp-content/uploads/2015/10/logo.png"/></a>
# </div>
# <nav class="themonic-nav" id="site-navigation" role="navigation">
# <a class="assistive-text" href="#content" title="Skip to content">Skip to content</a>
# <div class="menu-main_menu-container"><ul class="nav-menu" id="menu-top"><li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-77" id="menu-item-77"><a href="https://www.label-bank.co.jp/blog/category/foodlabel">食品表示</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-520" id="menu-item-520"><a href="https://www.label-bank.co.jp/blog/category/claims">強調表示</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-80" id="menu-item-80"><a href="https://www.label-bank.co.jp/blog/category/functional_foods">機能性表示</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-79" id="menu-item-79"><a href="https://www.label-bank.co.jp/blog/category/nutrition">栄養成分</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-85" id="menu-item-85"><a href="https://www.label-bank.co.jp/blog/category/allergy">アレルギー</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-post_tag menu-item-1893" id="menu-item-1893"><a href="https://www.label-bank.co.jp/blog/tag/%e5%8e%9f%e7%94%a3%e5%9c%b0">原産地</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-post_tag menu-item-1894" id="menu-item-1894"><a href="https://www.label-bank.co.jp/blog/tag/%e9%81%ba%e4%bc%9d%e5%ad%90%e7%b5%84%e6%8f%9b%e3%81%88">遺伝子組換え</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-post_tag menu-item-1895" id="menu-item-1895"><a href="https://www.label-bank.co.jp/blog/tag/%e6%94%b9%e6%ad%a3%e6%83%85%e5%a0%b1">改正情報</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-78" id="menu-item-78"><a href="https://www.label-bank.co.jp/blog/category/helpful_infomation">お役立ち</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-445" id="menu-item-445"><a href="https://www.label-bank.co.jp/blog/contact">お問い合わせ</a></li>
# </ul></div> </nav><!-- #site-navigation -->
# <div class="clear"></div>
# </header><!-- #masthead -->
# <div class="wrapper" id="main">
# <div class="site-content" id="primary">
# <div id="content" role="main">
# <article class="post-2639 post type-post status-publish format-standard hentry category-foodlabel tag-75 tag-50 tag-66 tag-foodlabel" id="post-2639">
# <header class="entry-header">
# <h2 class="entry-title">
# <a href="https://www.label-bank.co.jp/blog/foodlabel/202109additives" rel="bookmark" title="Permalink to 酒類の保存のため物品を混和することができる酒類の品目等を定める等の件の一部改正と酒類における添加物の留意点">酒類の保存のため物品を混和することができる酒類の品目等を定める等の件の一部改正と酒類における添加物の留意点</a>
# </h2>
# </header><!-- .entry-header -->
# <div class="entry-summary">
# <!-- Ico nic One home page thumbnail with custom excerpt -->
# <div class="excerpt-thumb">
# </div>
# <p>　6月25日に酒類の保存のため物品を混和することができる酒類の品目等を定める等の件の一部が改正され、「果実酒及び甘味果実酒」に「カゼインカリウム」が記載されました。酒類に使用する添加物については厚生労働省作成の食品添加物… <span class="read-more"><a href="https://www.label-bank.co.jp/blog/foodlabel/202109additives">つづきを読む »</a></span></p>
# </div><!-- .entry-summary -->
# <footer class="entry-meta">
# <span>2021年09月06日</span> | <span><a href="https://www.label-bank.co.jp/blog/category/foodlabel" rel="category tag">食品表示</a></span>
# </footer><!-- .entry-meta -->
# </article><!-- #post -->
# <article class="post-2630 post type-post status-publish format-standard hentry category-foodlabel tag-75 tag-foodlabel" id="post-2630">
# <header class="entry-header">
# <h2 class="entry-title">
# <a href="https://www.label-bank.co.jp/blog/foodlabel/
post type-post status-publish format-standard hentry category-foodlabel tag-75 tag-be tag-63 tag-79 tag-36 tag-81 tag-37 tag-58 tag-foodlabel" id="post-2490">
# <header class="entry-header">
# <h2 class="entry-title">
# <a href="https://www.label-bank.co.jp/blog/foodlabel/202106bioengineered-food" rel="bookmark" title="Permalink to 米国バイオ工学食品情報開示基準について～日本の遺伝子組換え表示制度との違いと輸出時の注意点～">米国バイオ工学食品情報開示基準について～日本の遺伝子組換え表示制度との違いと輸出時の注意点～</a>
# </h2>
# </header><!-- .entry-header -->
# <div class="entry-summary">
# <!-- Ico nic One home page thumbnail with custom excerpt -->
# <div class="excerpt-thumb">
# </div>
# <p>　2020年1月に施行された米国バイオ工学食品情報開示基準ですが、義務化となる2022年1月まであと半年となりました。これまで米国に食品を輸出されていた方はすでに取組をされていると思いますが、今後輸出を検討される方も多い… <span class="read-more"><a href="https://www.label-bank.co.jp/blog/foodlabel/202106bioengineered-food">つづきを読む »</a></span></p>
# </div><!-- .entry-summary -->
# <footer class="entry-meta">
# <span>2021年06月07日</span> | <span><a href="https://www.label-bank.co.jp/blog/category/foodlabel" rel="category tag">食品表示</a></span>
# </footer><!-- .entry-meta -->
# </article><!-- #post -->
# <article class="post-2478 post type-post status-publish format-standard hentry category-foodlabel tag-75 tag-50 tag-18 tag-foodlabel" id="post-2478">
# <header class="entry-header">
# <h2 class="entry-title">
# <a href="https://www.label-bank.co.jp/blog/foodlabel/202105additives" rel="bookmark" title="Permalink to 食品添加物の不使用表示に関するガイドラインについて">食品添加物の不使用表示に関するガイドラインについて</a>
# </h2>
# </header><!-- .entry-header -->
# <div class="entry-summary">
# <!-- Ico nic One home page thumbnail with custom excerpt -->
# <div class="excerpt-thumb">
# </div>
# <p>　2021年3月4日に第1回食品添加物の不使用表示に関するガイドライン検討会が開催されました。2019年度実施の「食品添加物表示制度に関する検討会」における意見等を踏まえ、食品添加物の不使用表示の実態を把握し、類型化する… <span class="read-more"><a href="https://www.label-bank.co.jp/blog/foodlabel/202105additives">つづきを読む »</a></span></p>
# </div><!-- .entry-summary -->
# <footer class="entry-meta">
# <span>2021年05月12日</span> | <span><a href="https://www.label-bank.co.jp/blog/category/foodlabel" rel="category tag">食品表示</a></span>
# </footer><!-- .entry-meta -->
# </article><!-- #post -->
# <article class="post-2472 post type-post status-publish format-standard hentry category-foodlabel tag-75 tag-64 tag-78 tag-foodlabel" id="post-2472">
# <header class="entry-header">
# <h2 class="entry-title">
# <a href="https://www.label-bank.co.jp/blog/foodlabel/202105foodlabel" rel="bookmark" title="Permalink to 改正食品表示法（食品リコール制度）の施行まで1ヶ月となりました">改正食品表示法（食品リコール制度）の施行まで1ヶ月となりました</a>
# </h2>
# </header><!-- .entry-header -->
# <div class="entry-summary">
# <!-- Ico nic One home page thumbnail with custom excerpt -->
# <div class="excerpt-thumb">
# </div>
# <p>　平成30年（2018年）12月14日に公布された「食品表示法の一部を改正する法律」が、今年、令和3年（2021年）6月1日に施行されます。改正内容のポイントを再確認すると以下のとおりです。 ＜改正の概要＞ 自主回収を行… <span class="read-more"><a href="https://www.label-bank.co.jp/blog/foodlabel/202105foodlabel">つづきを読む »</a></span></p>
# </div><!-- .entry-summary -->
# <footer class="entry-meta">
# <span>2021年05月12日</span> | <span><a href="https://www.label-bank.co.jp/blog/category/foodlabel" rel="category tag">食品表示</a></span>
# </footer><!-- .entry-meta -->
# </article><!-- #post -->
# <nav class="navigation" id="nav-below" role="navigation">
# <div class="assistive-text">Post navigation</div>
# <div class="nav-previous alignleft"><a href="https://www.label-bank.co.jp/blog/page/2"><span class="meta-nav">←</span> 古い投稿へ</a></div>
# <div class="nav-next alignright"></div>
# </nav><!-- #nav-below .navigation -->
# </div><!-- #content -->
# </div><!-- #primary -->
# <div class="widget-area" id="secondary" role="complementary">
# <aside class="widget widget_text" id="text-7"><p class="widget-title">食品表示ブログについて</p> <div class="textwidget">2015年10月、ラベルバンクのコラムサイトがリニューアルし、より読みやすくなりました！
#
# 食品表示に関わる人たちのヒントになれれば幸いです。
# 今後ともどうぞよろしくお願いいたします。</div>
# </aside><aside class="widget widget_text" id="text-4"><p class="widget-title">運営会社</p> <div class="textwidget"><p class="cen" style="margin-bottom:-10px;"><a href="https://www.label-bank.co.jp/" target='_blanc"'><img alt="ラベルバンク" border="0" src="https://www.label-bank.co.jp/blog/img/labelbank_logo.png"/></a></p>
# <p><a href="https://www.label-bank.co.jp/" target='_blank"'>ラベルバンク</a>は、原材料リサーチや食品表示チェック、作成をはじめとする『食品表示』にかかわるサービスをご提供しています。この食品表示blogでは、毎月「原材料」「栄養成分」「原産地」など食品表示にかかわるコラムをお届けしています。<br/>&gt;&gt; <a href="https://www.label-bank.co.jp/" target='_blank"'>コーポレートサイト</a></p>
# <a href="https://www.label-bank.co.jp/blog/company"><img alt="会社情報" src="https://www.label-bank.co.jp/blog/img/btn01.jpg" width="100%"/></a>
# <a href="https://www.label-bank.co.jp/blog/service"><img alt="主要サービス紹介" src="https://www.label-bank.co.jp/blog/img/btn02.jpg" width="100%"/></a>
# <!--<a href="https://www.label-bank.co.jp/blog/mailmagazine" ><img src="https://www.label-bank.co.jp/blog/img/btn03.jpg" alt="メールマガジン配信登録" width="100%" /></a>--></div>
# </aside><aside class="widget widget_text" id="text-8"><p class="widget-title">メールマガジン配信登録</p> <div class="textwidget">食品表示に関するニュースやセミナー情報を、ご登録されたメールアドレス宛に送付させていただきます。<br/><br/>
# <!--JB Tracker--> <script type="text/javascript"> var _paq = _paq || []; (function(){ if(window.apScriptInserted) return; _paq.push(['clientToken', 'P%2bsIjEMd6oQ%3d']); var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0]; g.type='text/javascript'; g.async=true; g.defer=true; g.src='https://prod.benchmarkemail.com/tracker.bundle.js'; s.parentNode.insertBefore(g,s); window.apScriptInserted=true;})(); </script> <!--/JB Tracker--> <!-- BEGIN: Signup Form Popup Code from Benchmark Email Ver 4.0  -->
# <style type="text/css">
#  .formbox-editor_7BVXX fieldset {border: none;margin: 0;padding: 0 40px;position: relative;}
#  .formbox-editor_7BVXX fieldset > input,.formbox-editor_7BVXX fieldset > textarea,.formbox-editable-field_7BVXX {margin: 10px 0;outline: none;}
#  .spacer-block_7BVXX {min-height: 20px;padding: 10px 0;position: relative;}
#  .spacer-block-line_7BVXX {position: absolute;top: 50%;left: 40px;right: 40px;display: none;border-top-style: solid;}
#  .formbox-editor_7BVXX {margin: 0 auto;padding: 0;text-align: left;width: 100%;box-sizing: border-box;}
#  #formbox_screen_subscribe_7BVXX, #formbox_screen_success_7BVXX {padding: 30px 0;}
#  .formbox-title_7BVXX, .formbox-text-field_7BVXX {margin-bottom: 0; font-family: Helvetica, Arial, sans-serif; color: #000000; font-size: 12px; }
#  .formbox-title_7BVXX a, .formbox-text-field_7BVXX a  {text-decoration: none;}
#  .formbox-title_7BVXX p, .formbox-text-field_7BVXX p {margin: 0;margin-bottom: 10px;padding: 0; word-break: break-word;}
#
#  label.formbox-field-label_7BVXX {font-family: Helvetica, Arial, sans-serif; display: block; margin: 10px 0 0; padding: 0; font-size: 14px; text-align: left;line-height: 100%; color: #000000;}
#  label.formbox-label-wrap_7BVXX {font-family: Helvetica, Arial, sans-serif; display: block; margin: 10px 0 0; padding: 0; font-size: 12px; line-height: 100%; padding-left: 15px; text-indent: -15px; font-style: italic;color: #000000;} label.formbox-label-wrap_7BVXX:last-of-type {margin-bottom: 10px;}
#  label.formbox-label-wrap_7BVXX input[type=checkbox], label.formbox-label-wrap_7BVXX input[type=radio] { width: 13px; height: 13px; padding: 0; margin:0; margin-right: 5px; vertical-align: bottom; position: relative; top: -1px; }
#  select.formbox-field_7BVXX {background-color: #000000; border: 2px solid #f1f2f2; border-radius: 0px; box-sizing: border-box; background-color: #ffffff; font-family: Helvetica, Arial, sans-serif; font-size: 12px; width: 100%; margin: 10px 0; height: auto; padding: 2px 0px;}
#
#  input.formbox-field_7BVXX {color: #000000; background-color: #ffffff; border: 2px solid #f1f2f2; border-radius:0px; font-family: Helvetica, Arial, sans-serif; font-size: 12px; box-sizing: border-box; padding:15px; width: 100%;} input.formbox-field_7BVXX.text-placeholder {color: #c4c4c4; font-weight: normal; font-style: normal; font-family: Helvetica, Arial, sans-serif; font-size: 12px;}
#  .formbox-field_7BVXX::-webkit-input-placeholder {color: #c4c4c4; font-weight: normal; font-style: normal;opacity: 1;}
#  .formbox-field_7BVXX::-moz-placeholder { color: #c4c4c4; font-weight: normal; font-style: normal;opacity: 1;}
#  .formbox-field_7BVXX:-ms-input-placeholder {color: #c4c4c4; font-weight: normal; font-style: normal; opacity: 1;}
#  .formbox-button_7BVXX {line-height: 100%;  cursor: pointer; margin: 10px 0; }
#  .formbox-button_7BVXX:hover { background-color:#2ab5fb !important; }
#  .formbox-button_7BVXX:active { background-color:#028dd3 !important; }
# #popupFormLoader_7BVXX { display: none; position: absolute; bottom: 10px; right: 10px; width: 20px; height: 20px; background-image: url(https://benchmarkemail.com/images/popup-builder/loadingicon.svg); background-position: center center; background-repeat: no-repeat; background-color: rgb(255, 255, 255); background-color: rgba(255, 255, 255, 0.3);  border-radius: 100%; -webkit-animation-name: spin; -webkit-animation-duration: 800ms; -webkit-animation-iteration-count: infinite; -webkit-animation-timing-function: linear; -moz-animation-name: spin; -moz-animation-duration: 800ms; -moz-animation-iteration-count: infinite; -moz-animation-timing-function: linear;
# -ms-animation-name: spin;-ms-animation-duration: 800ms;-ms-animation-iteration-count: infinite;-ms-animation-timing-function: linear;animation-name: spin;animation-duration: 800ms;animation-iteration-count: infinite;animation-timing-function: linear;}
#
# </style>
# <div id="signupFormContainer_7BVXX">
# <div id="signupFormContent_7BVXX">
# <div class="formbox-editor_7BVXX" style="background: #ffffff;
# border-color:#f1f2f2; border-style: solid; border-width:1px;border-radius:0px; box-sizing: border-box; top: 0px;"><div id="formbox_screen_subscribe_7BVXX" name="frmLB_7BVXX" style="display:block;">
# <input id="token_7BVXX" name="token_7BVXX" type="hidden" value="mFcQnoBFKMQAw8CDs7n8cRcwvUXpuXVDAWDo1Lzs5cwCdBXyU8FEHw%3D%3D"/>
# <input id="successurl_7BVXX" name="successurl_7BVXX" type="hidden" value="https://lb.benchmarkemail.com/Code/ThankYouOptin?language=japanese"/>
# <input id="errorurl_7BVXX" name="errorurl_7BVXX" type="hidden" value="http://lb.benchmarkemail.com//Code/Error"/>
# <fieldset class="formbox-field_7BVXX"><input class="formbox-field_7BVXX text-placeholder" id="fldlastname_7BVXX" maxlength="100" name="fldlastname_7BVXX" onblur="javascript:blurPlaceHolder(this);" onfocus="javascript:focusPlaceHolder(this);" placeholder="姓" type="text"/></fieldset>
# <fieldset class="formbox-field_7BVXX"><input class="formbox-field_7BVXX text-placeholder" id="fldfirstname_7BVXX" maxlength="100" name="fldfirstname_7BVXX" onblur="javascript:blurPlaceHolder(this);" onfocus="javascript:focusPlaceHolder(this);" placeholder="名" type="text"/></fieldset>
# <fieldset class="formbox-field_7BVXX"><input class="formbox-field_7BVXX text-placeholder" id="fldfield9_7BVXX" maxlength="100" name="fldfield9_7BVXX" onblur="javascript:blurPlaceHolder(this);" onfocus="javascript:focusPlaceHolder(this);" placeholder="法人名" type="text"/></fieldset>
# <fieldset class="formbox-field_7BVXX"><input class="formbox-field_7BVXX text-placeholder" id="fldemail_7BVXX" maxlength="100" name="fldemail_7BVXX" onblur="javascript:blurPlaceHolder(this);" onfocus="javascript:focusPlaceHolder(this);" placeholder="メールアドレス *" type="text"/></fieldset>
# <fieldset style="text-align:center;"><div class="formbox-button_7BVXX" id="btnSubmit_7BVXX" onclick="javascript:return submit_7BVXXClick();" style="word-break: break-all; box-sizing: border-box; text-align:center; display: inline-block;width: 100%;padding-left: 15px; padding-right: 15px;padding-top: 15px; padding-bottom: 15px;background-color:rgb(22, 161, 231); border: rgba(0, 0, 0, 0) solid 0px; border-radius: 2px;font-family :Helvetica, Arial, sans-serif; font-size: 14px;color: rgb(255, 255, 255); line-height: 1; letter-spacing:1pxpx;">認証メールを送信する</div></fieldset></div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# function CheckField_7BVXX(fldName, frm){var fldObj = document.getElementsByName(fldName);if ( fldObj.length > 1 ) {  for ( var i = 0, l = fldObj.length; i < l; i++ ) {   if ( fldObj[0].type == 'select-one' ) { if( fldObj[i].selected && i==0 && fldObj[i].value == '' ) { return false; }   if ( fldObj[i].selected ) { return true; } }  else { if ( fldObj[i].checked ) { return true; } }; } return false; }  else  { if ( fldObj[0].type == "checkbox" ) { return ( fldObj[0].checked ); }  else if ( fldObj[0].type == "radio" ) { return ( fldObj[0].checked ); }  else { fldObj[0].focus(); return (fldObj[0].value.length > 0); }} }
# function rmspaces(x) {var leftx = 0;var rightx = x.length -1;while ( x.charAt(leftx) == ' ') { leftx++; }while ( x.charAt(rightx) == ' ') { --rightx; }var q = x.substr(leftx,rightx-leftx + 1);if ( (leftx == x.length) && (rightx == -1) ) { q =''; } return(q); }
#
# function checkfield(data) {if (rmspaces(data) == ""){return false;}else {return true;}}
#
# function isemail(data) {var flag = false;if (  data.indexOf("@",0)  == -1 || data.indexOf("\\",0)  != -1 ||data.indexOf("/",0)  != -1 ||!checkfield(data) ||  data.indexOf(".",0)  == -1  ||  data.indexOf("@")  == 0 ||data.lastIndexOf(".") < data.lastIndexOf("@") ||data.lastIndexOf(".") == (data.length - 1)   ||data.lastIndexOf("@") !=   data.indexOf("@") ||data.indexOf(",",0)  != -1 ||data.indexOf(":",0)  != -1 ||data.indexOf(";",0)  != -1  ) {return flag;} else {var temp = rmspaces(data);if (temp.indexOf(' ',0) != -1) { flag = true; }var d3 = temp.lastIndexOf('.') + 4;var d4 = temp.substring(0,d3);var e2 = temp.length  -  temp.lastIndexOf('.')  - 1;var i1 = temp.indexOf('@');if (  (temp.charAt(i1+1) == '.') || ( e2 < 1 ) ) { flag = true; }return !flag;}}
#
# function focusPlaceHolder(obj) {
# obj.className = "formbox-field_7BVXX"; }
# function blurPlaceHolder(obj) {
# if ( obj.value == '' ) { obj.className = "formbox-field_7BVXX text-placeholder"; } }
# function isValidDate(year, month, day) {
# if (year.toString() == '' || month.toString() == '' || day.toString() == '') { return false;} try { year = parseInt(year); month = parseInt(month); day = parseInt(day); } catch (e) { return false;} var d = new Date(year, month - 1, day, 0, 0, 0, 0); return (!isNaN(d) && (d.getDate() == day && d.getMonth() + 1 == month && d.getFullYear() == year));}var submitButton_7BVXX = document.getElementById("btnSubmit_7BVXX");
# var subscribeScreen_7BVXX = document.getElementById("formbox_screen_subscribe_7BVXX");
# var signupFormContainer_7BVXX = document.getElementById("signupFormContainer_7BVXX");
# var signupFormLoader_7BVXX = document.getElementById("popupFormLoader_7BVXX");
# function submit_7BVXXClick(){
#  var retVal = true; var contentdata = ""; var frm = document.getElementById("formbox_screen_subscribe_7BVXX");if ( !isemail(document.getElementsByName("fldemail_7BVXX")[0].value) ) {
#    alert("\u30E1\u30FC\u30EB\u30A2\u30C9\u30EC\u30B9 \u3092\u3054\u8A18\u5165\u304F\u3060\u3055\u3044\u3002");
# document.getElementById("fldemail_7BVXX").focus(); retVal = false;} if ( retVal == true ) {var frm = "_7BVXX"; var f = document.createElement("form"); f.setAttribute('accept-charset', "UTF-8");  f.setAttribute('method', "post"); f.setAttribute('action', "https://lb.benchmarkemail.com//code/lbform"); var elms = document.getElementsByName("frmLB" + frm)[0].getElementsByTagName("*");var ty = ""; for (var ei = 0; ei < elms.length; ei++) {ty = elms[ei].type; if (ty == "hidden" || ty == "text" || (ty == "checkbox" && elms[ei].checked) || (ty == "radio" && elms[ei].checked) || ty == "textarea" || ty == "select-one" || ty == "button") {elm = elms[ei]; if(elm.id != "") { var i = document.createElement("input"); i.type = "hidden"; i.name = elm.name.replace("_7BVXX", ""); i.id = elm.id; i.value = elm.value; f.appendChild(i); } } } document.getElementsByTagName('body')[0].appendChild(f);f.submit(); }
# if(isemail(document.getElementById("fldemail_7BVXX").value) && window && window.JB_TRACKER && typeof window.JB_TRACKER.jbSubmitForm === 'function') {
#  window.JB_TRACKER.jbSubmitForm({
#  email: document.getElementById("fldemail_7BVXX").value, didSubmit: true
#  });
#  }
#
# return retVal;}  var bmePopupFormViewed_7BVXX = localStorage.getItem('bmePopupFormSignedUp1469316');
#   if ( bmePopupFormViewed_7BVXX != 'true') {
#   }
# function debounce_7BVXX(func, wait, immediate) {
# var timeout;
# return function() {
# var context = this, args = arguments;
# var later = function() {timeout = null; if (!immediate) func.apply(context, args); };
# var callNow = immediate && !timeout; clearTimeout(timeout); timeout = setTimeout(later, wait); if (callNow) func.apply(context, args); };
# };
# var hasVerticalCenter_7BVXX = document.getElementsByClassName('position-centered');
# function verticalCenter_7BVXX(element) { if(element) { element.style.opacity = 0;  element.style.display = 'block';  }
# setTimeout(function () { if (hasVerticalCenter_7BVXX.length > 0) { var windowHeight = Math.max(document.documentElement.clientHeight, window.innerHeight || 0);
#  var formElement_7BVXX = document.getElementsByClassName('formbox-editor_7BVXX')[0]; var formHeight_7BVXX = formElement_7BVXX.clientHeight;
#  if (formHeight_7BVXX < windowHeight) { var newPosition = 0; newPosition = (windowHeight - formHeight_7BVXX) / 2; formElement_7BVXX.style.top = newPosition + 'px'; } else { formElement_7BVXX.style.top = '0px'; } }
# if(element) { element.style.opacity = 1;  }
#  }, 100);
# }
# if (hasVerticalCenter_7BVXX.length > 0) { var resizeEvent_7BVXX = debounce_7BVXX(function() { verticalCenter_7BVXX(); }, 250); window.addEventListener('resize', resizeEvent_7BVXX); }
#
# </script>
# <!-- END: Signup Form Popup Code from Benchmark Email Ver 4.0  -->
# </div>
# </aside><aside class="widget widget_text" id="text-5"><p class="widget-title">おすすめ食品表示サービス</p> <div class="textwidget"><a href="https://www.label-bank.co.jp/jp_market/" target="_blank"><img alt="食品表示作成・チェックサービス（国産食品、輸入食品）" src="https://www.label-bank.co.jp/blog/img/jp_market.gif" width="auto"/></a>
# <a href="https://www.label-bank.co.jp/ovs_markets/" target="_blank"><img alt="食品表示作成・チェックサービス（海外向け、輸出食品）" src="https://www.label-bank.co.jp/blog/img/ovs_markets.gif" width="auto"/></a>
#
# &gt;&gt; <a href="https://www.label-bank.co.jp/foodlabelservice/" target="_blank">原材料と食品表示に関する総合サポートサービスはこちら</a></div>
# </aside> <aside class="widget widget_recent_entries" id="recent-posts-3"> <p class="widget-title">新着記事</p> <ul>
# <li>
# <a href="https://www.label-bank.co.jp/blog/foodlabel/202109additives">酒類の保存のため物品を混和することができる酒類の品目等を定める等の件の一部改正と酒類における添加物の留意点</a>
# <span class="post-date">2021年9月6日</span>
# </li>
# <li>
# <a href="https://www.label-bank.co.jp/blog/foodlabel/202109foodlabel">食品表示の全体像に関する提言に基づく「空間的情報量に関する調査」「アプリケーションを活用した食品表示実証調査」 報告書が公表されました</a>
# <span class="post-date">2021年9月6日</span>
# </li>
# <li>
# <a href="https://www.label-bank.co.jp/blog/foodlabel/202108foodlabel">新たな加工食品の原料原産地表示制度～経過措置期間終了まで約半年となりました～</a>
# <span class="post-date">2021年8月6日</span>
# </li>
# <li>
# <a href="https://www.label-bank.co.jp/blog/foodlabel/202108singapore">シンガポール　個別食品規格を削除する改定について意見募集</a>
# <span class="post-date">2021年8月6日</span>
# </li>
# <li>
# <a href="https://www.label-bank.co.jp/blog/helpful_infomation/202107additives">EU諸国におけるナノ材料（nano material）としての添加物の安全性に対する考え方について（二酸化チタンの事例に見る）</a>
# <span class="post-date">2021年7月7日</span>
# </li>
# </ul>
# </aside>
# <!-- WordPress Popular Posts Plugin v3.3.3 [W] [monthly] [views] [regular] -->
# <aside class="widget popular-posts" id="wpp-2">
# <p class="widget-title">人気の記事</p>
# <ul class="wpp-list">
# <li><a href="https://www.label-bank.co.jp/blog/foodlabel/202004frozen-chilled-food" target="_self" title="フローズンチルド商品の表示についての注意点"><img alt="フローズンチルド商品の表示についての注意点" class="wpp-thumbnail wpp_def_noPath wpp_featured" src="https://www.label-bank.co.jp/blog/wp-content/plugins/wordpress-popular-posts/no_thumb.jpg" title="フローズンチルド商品の表示についての注意点"/></a> <a class="wpp-post-title" href="https://www.label-bank.co.jp/blog/foodlabel/202004frozen-chilled-food" target="_self" title="フローズンチルド商品の表示についての注意点">フローズンチルド商品の表示についての注意点</a> <span class="wpp-excerpt">　「フロチル」という言葉をご存知ですか？「フローズ...</span> <span class="post-stats"><span class="wpp-date">posted on 2020年4月8日</span></span> </li>
# <a class="tag-link-38" href="https://www.label-bank.co.jp/blog/tag/%e8%bc%b8%e5%85%a5" style="font-size: 10.3595505618pt;" title="3件のトピック">輸入</a>
# <a class="tag-link-37" href="https://www.label-bank.co.jp/blog/tag/%e8%bc%b8%e5%87%ba" style="font-size: 14.3707865169pt;" title="12件のトピック">輸出</a>
# <a class="tag-link-58" href="https://www.label-bank.co.jp/blog/tag/%e9%81%ba%e4%bc%9d%e5%ad%90%e7%b5%84%e6%8f%9b%e3%81%88" style="font-size: 13.1123595506pt;" title="8件のトピック">遺伝子組換え</a>
# <a class="tag-link-66" href="https://www.label-bank.co.jp/blog/tag/%e9%85%92%e9%a1%9e" style="font-size: 9.41573033708pt;" title="2件のトピック">酒類</a>
# <a class="tag-link-2" href="https://www.label-bank.co.jp/blog/tag/foodlabel" style="font-size: 22pt;" title="119件のトピック">食品表示</a></div>
# </aside> </div><!-- #secondary -->
# </div><!-- #main .wrapper -->
# <footer id="colophon" role="contentinfo">
# <nav>
# <ul id="footer-nav"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-525" id="menu-item-525"><a href="https://ssl.label-bank.co.jp/blog/">ホーム</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-533" id="menu-item-533"><a href="https://www.label-bank.co.jp/blog/company">会社情報</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-532" id="menu-item-532"><a href="https://www.label-bank.co.jp/blog/service">食品表示サービスのご紹介</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-529" id="menu-item-529"><a href="https://www.label-bank.co.jp/blog/copyright">著作権・リンクについて</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-531" id="menu-item-531"><a href="https://www.label-bank.co.jp/blog/contact">お問い合わせ</a></li>
# </ul></nav>
# <div class="site-info">
# <div class="footercopy"><a href="https://www.label-bank.co.jp/privacy/" target="_blank">個人情報保護方針</a><br/>
# © 2013 Label bank Co., Ltd.</div>
# <div class="footercredit">食品表示ブログは<a href="https://www.label-bank.co.jp/" target="_blank">ラベルバンク</a>が運営しています。</div>
# <div class="clear"></div>
# </div><!-- .site-info -->
# </footer><!-- #colophon -->
# <div class="site-wordpress">
# <span class="white"><a href="http://themonic.com/iconic-one/">Iconic One</a> Theme</span>
# </div><!-- .site-info -->
# <div class="clear"></div>
# </div><!-- #page -->
# <div class="scroll-back-to-top-wrapper">
# <span class="scroll-back-to-top-inner">
# <i class="fa fa-2x fa-chevron-circle-up"></i>
# </span>
# </div><!-- BEGIN: WP Social Bookmarking Light -->
# <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0],p=/^http:/.test(d.location)?'http':'https';if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src=p+'://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document, 'script', 'twitter-wjs');</script>
# <script async="" defer="" src="https://apis.google.com/js/platform.js">{lang: "ja"}</script>
# <!-- END: WP Social Bookmarking Light -->
# <script type="text/javascript">
# /* <![CDATA[ */
# var scrollBackToTop = {"scrollDuration":"500","fadeDuration":"0.5"};
# /* ]]> */
# </script>
# <script src="https://www.label-bank.co.jp/blog/wp-content/plugins/scroll-back-to-top/assets/js/scroll-back-to-top.js" type="text/javascript"></script>
# <script src="https://www.label-bank.co.jp/blog/wp-content/themes/iconic-one/js/selectnav.js?ver=1.0" type="text/javascript"></script>
# <script src="https://www.label-bank.co.jp/blog/wp-includes/js/wp-embed.min.js?ver=4.4.25" type="text/javascript"></script>
# </body>
# </html>

# %%
elems = soup.find_all("content")
elems
# Out:
# []
