# %%
import pandas as pd

# %%
df=pd.read_excel('C:/Users/polif/Documents/MYpython/英語テストVBA.xlsx')
df
# Out:
#                                             Unnamed: 0  \
# 0                    Do not meddle in others' affairs!
# 1                                                  NaN
# 2    I'm so relieved that I don't have to make a sp...
# 3                                                  NaN
# 4                               have had it up to here
# ..                                                 ...
# 151   A cop saw me run a red light, but he let me off.
# 152         If you have lied to me, just own up to it!
# 153                                                NaN
# 154                                                NaN
# 155                                she went to pieces.
#
#                Unnamed: 0.1  \
# 0                   お節介をやくな
# 1                       NaN
# 2                   肩の荷がおりる
# 3                       NaN
# 4                 もう我慢できない！
# ..                      ...
# 151  警察は私の信号無視を見たが、見逃してくれた。
# 152         嘘ついてたなら、白状しなさい！
# 153                     NaN
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38'],
#       dtype='object')

# %%
df = df.iloc[:,0:3]
df
# Out:
#                                             Unnamed: 0  \
# 0                    Do not meddle in others' affairs!
# 1                                                  NaN
# 2    I'm so relieved that I don't have to make a sp...
# 3                                                  NaN
# 4                               have had it up to here
# ..                                                 ...
# 151   A cop saw me run a red light, but he let me off.
# 152         If you have lied to me, just own up to it!
# 153                                                NaN
# 154                                                NaN
# 155                                she went to pieces.
#
#                Unnamed: 0.1                                         Unnamed: 2
# 0                   お節介をやくな                 Do not  ------ in others' affairs!
# 1                       NaN                                                NaN
# ...

# %%
df.columns=['英文','日本文','問題']
df
# Out:
#                                                     英文  \
# 0                    Do not meddle in others' affairs!
# 1                                                  NaN
# 2    I'm so relieved that I don't have to make a sp...
# 3                                                  NaN
# 4                               have had it up to here
# ..                                                 ...
# 151   A cop saw me run a red light, but he let me off.
# 152         If you have lied to me, just own up to it!
# 153                                                NaN
# 154                                                NaN
# 155                                she went to pieces.
#
#                         日本文                                                 問題
# 0                   お節介をやくな                 Do not  ------ in others' affairs!
# 1                       NaN                                                NaN
# ...
